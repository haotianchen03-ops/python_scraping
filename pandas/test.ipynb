# %% [markdown]
# ## jupyter notebook

# %%
import pandas as pd
import random

# %%
data = pd.DataFrame({'name':('chen','wang','liu'),'age':[11,23,42]})
data
# Out:
#    name  age
# 0  chen   11
# 1  wang   23
# 2   liu   42

# %%
nums = list(range(1,4))
random.shuffle(nums)
nums
# Out:
# [3, 2, 1]

# %%
data_new = data.assign(
     num = nums
).copy()

# %%
data_new.drop(0,axis = 0)
# Out:
#    name  age  num
# 1  wang   23    2
# 2   liu   42    1
